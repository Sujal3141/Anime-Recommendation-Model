# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujal3141/Anime-Recommendation-Model/blob/main/Anime_Recomedation_System_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import ast

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/colab /Recommendation System/Anime_data.csv")

# %%
df.head()
# Out:
#    Anime_id                            Title  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8                   Bouken Ou Beet
#
#                                                Genre  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...
#
#                                             Synopsis   Type  \
# 0  In the year 2071, humanity has colonized sever...     TV
# 1  Another day, another bounty—such is the life o...  Movie
# 2  Vash the Stampede is the man with a $$60,000,0...     TV
# 3  Witches are individuals with special powers li...     TV
# 4  It is the dark century and the people are suff...     TV
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17002 entries, 0 to 17001
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Anime_id    17002 non-null  int64
#  1   Title       17002 non-null  object
#  2   Genre       14990 non-null  object
#  3   Synopsis    15583 non-null  object
#  4   Type        16368 non-null  object
#  5   Producer    7635 non-null   object
#  6   Studio      7919 non-null   object
#  7   Rating      14425 non-null  float64
#  8   ScoredBy    13227 non-null  float64
#  9   Popularity  16368 non-null  float64
#  10  Members     17002 non-null  float64
#  11  Episodes    14085 non-null  float64
#  12  Source      15075 non-null  object
#  13  Aired       16368 non-null  object
#  14  Link        16368 non-null  object
# dtypes: float64(5), int64(1), object(9)
# memory usage: 1.9+ MB

# %%
anime = df[['Anime_id','Title','Genre','Synopsis']]

# %%
anime.head()
# Out:
#    Anime_id                            Title  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8                   Bouken Ou Beet
#
#                                                Genre  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...
#
#                                             Synopsis
# 0  In the year 2071, humanity has colonized sever...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Witches are individuals with special powers li...
# 4  It is the dark century and the people are suff...

# %%
anime.shape
# Out:
# (17002, 4)

# %%
anime.isnull().sum()
# Out:
# Anime_id       0
# Title          0
# Genre       2012
# Synopsis    1419
# dtype: int64

# %%
 anime.dropna(inplace=True)
# Out:
# <ipython-input-10-8959164b7c08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime.dropna(inplace=True)

# %%
anime.shape
# Out:
# (13743, 4)

# %%
anime.duplicated().sum()
# Out:
# 96

# %%
anime = anime.drop_duplicates()

# %%
anime.shape
# Out:
# (13647, 4)

# %%
anime.duplicated().sum()
# Out:
# 0

# %%
anime
# Out:
#        Anime_id                            Title  \
# 0             1                     Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira
# 2             6                           Trigun
# 3             7               Witch Hunter Robin
# 4             8                   Bouken Ou Beet
# ...         ...                              ...
# 15061     40055                      Orbital Era
# 15063     40057            Akai Hana Shiroi Hana
# 15064     40058                    Arui Tekoteko
# 15065     40059          Golden Kamuy 3rd Season
# 15074     40074                          Gibiate
#
#                                                    Genre  \
# 0      ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1      ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# 2      ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...
# 3      ['Action', 'Magic', 'Police', 'Supernatural', ...
# 4      ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...
# ...

# %%
# anime['Synopsis']=anime['Synopsis'].apply(lambda x:x.split() )

# %%
anime.head()
# Out:
#    Anime_id                            Title  \
# 0         1                     Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira
# 2         6                           Trigun
# 3         7               Witch Hunter Robin
# 4         8                   Bouken Ou Beet
#
#                                                Genre  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...
#
#                                             Synopsis
# 0  In the year 2071, humanity has colonized sever...
# 1  Another day, another bounty—such is the life o...
# 2  Vash the Stampede is the man with a $$60,000,0...
# 3  Witches are individuals with special powers li...
# 4  It is the dark century and the people are suff...

# %%
for i in anime.index:
  try:
    anime['Genre'][i]=ast.literal_eval(anime['Genre'][i])
  except Exception as e:
    continue
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-19-7c7e049add41>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime['Genre'][i]=ast.literal_eval(anime['Genre'][i])
# <ipython-input-19-7c7e049add41>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime['Genre'][i]=ast.literal_eval(anime['Genre'][i])
# <ipython-input-19-7c7e049add41>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
anime['tags']=''
for i in anime.index:
  try:
    if isinstance(anime['Genre'][i], list):
            str1 = ' '.join(anime['Genre'][i])
            anime.loc[i, 'tags'] = str1
  except Exception as e:
    continue

# %%
for i in anime.index:
  try:
            str1=" "
            str1 += anime['Synopsis'][i]
            anime.loc[i, 'tags'] += str1
  except Exception as e:
    continue

# %%
anime['tags'][12000]
# Out:
# "Kids Music The poem  Watashi to Kotori to Suzu to  was originally written by Misuzu Kaneko. Composer Ryuichi Sugimoto converted the poem into a song and it was sung by Aragaki Tsutomu. This song was animated for NHK's  Minna no Uta  program."

# %%
for i in anime.index:
    if anime.loc[i, 'Title'] == "Orbital Era":
        print(i,anime.loc[i, 'tags'])
        break
# Out:
# 15061 Action Adventure Fantasy Sci-Fi Space Orbital Era  is set in the near-future on a space colony under construction. The film features a coming-of-age action-adventure story following the lives of young boys surviving in this peculiar environment and society as they are tossed around by fate. "The reality found in mankind's future" will be depicted through their perspective.
#
# The story will take place over four seasons in the space colony. The characters relationships will unfold over these seasons. Otomo noted that the film is set in the future, but instead of being rooted in science fiction, the story will skew more toward fantasy.
#
# (Source: MAL News)

# %%
anime['tags'][15061]
# Out:
# 'Action Adventure Fantasy Sci-Fi Space Orbital Era  is set in the near-future on a space colony under construction. The film features a coming-of-age action-adventure story following the lives of young boys surviving in this peculiar environment and society as they are tossed around by fate. "The reality found in mankind\'s future" will be depicted through their perspective. \r\n \r\nThe story will take place over four seasons in the space colony. The characters relationships will unfold over these seasons. Otomo noted that the film is set in the future, but instead of being rooted in science fiction, the story will skew more toward fantasy. \r\n \r\n(Source: MAL News)'

# %%
anime['Genre'][15061]
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Space']

# %%
anime['Synopsis'][15061]
# Out:
# 'Orbital Era  is set in the near-future on a space colony under construction. The film features a coming-of-age action-adventure story following the lives of young boys surviving in this peculiar environment and society as they are tossed around by fate. "The reality found in mankind\'s future" will be depicted through their perspective. \r\n \r\nThe story will take place over four seasons in the space colony. The characters relationships will unfold over these seasons. Otomo noted that the film is set in the future, but instead of being rooted in science fiction, the story will skew more toward fantasy. \r\n \r\n(Source: MAL News)'

# %%
anime
# Out:
#        Anime_id                            Title  \
# 0             1                     Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira
# 2             6                           Trigun
# 3             7               Witch Hunter Robin
# 4             8                   Bouken Ou Beet
# ...         ...                              ...
# 15061     40055                      Orbital Era
# 15063     40057            Akai Hana Shiroi Hana
# 15064     40058                    Arui Tekoteko
# 15065     40059          Golden Kamuy 3rd Season
# 15074     40074                          Gibiate
#
#                                                    Genre  \
# 0      [Action, Adventure, Comedy, Drama, Sci-Fi, Space]
# 1                [Action, Space, Drama, Mystery, Sci-Fi]
# 2      [Action, Sci-Fi, Adventure, Comedy, Drama, Sho...
# 3      [Action, Magic, Police, Supernatural, Drama, M...
# 4            [Adventure, Fantasy, Shounen, Supernatural]
# ...

# %%
anime.drop(['Genre','Synopsis'],axis=1,inplace=True)

# %%
anime
# Out:
#        Anime_id                            Title  \
# 0             1                     Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira
# 2             6                           Trigun
# 3             7               Witch Hunter Robin
# 4             8                   Bouken Ou Beet
# ...         ...                              ...
# 15061     40055                      Orbital Era
# 15063     40057            Akai Hana Shiroi Hana
# 15064     40058                    Arui Tekoteko
# 15065     40059          Golden Kamuy 3rd Season
# 15074     40074                          Gibiate
#
#                                                     tags
# 0      Action Adventure Comedy Drama Sci-Fi Space In ...
# 1      Action Space Drama Mystery Sci-Fi Another day,...
# 2      Action Sci-Fi Adventure Comedy Drama Shounen V...
# 3      Action Magic Police Supernatural Drama Mystery...
# 4      Adventure Fantasy Shounen Supernatural It is t...
# ...

# %%
anime['tags'] = anime['tags'].apply(lambda x:x.lower())

# %%
anime
# Out:
#        Anime_id                            Title  \
# 0             1                     Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira
# 2             6                           Trigun
# 3             7               Witch Hunter Robin
# 4             8                   Bouken Ou Beet
# ...         ...                              ...
# 15061     40055                      Orbital Era
# 15063     40057            Akai Hana Shiroi Hana
# 15064     40058                    Arui Tekoteko
# 15065     40059          Golden Kamuy 3rd Season
# 15074     40074                          Gibiate
#
#                                                     tags
# 0      action adventure comedy drama sci-fi space in ...
# 1      action space drama mystery sci-fi another day,...
# 2      action sci-fi adventure comedy drama shounen v...
# 3      action magic police supernatural drama mystery...
# 4      adventure fantasy shounen supernatural it is t...
# ...

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
  def stem(text):
    y=[]
    for i in text.split():
      y.append(ps.stem(i))
    return " ".join(y)

# %%
anime['tags']=anime['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(anime['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cv.get_feature_names_out()
# Out:
# array(['000', '01', '10', ..., 'zombie', 'zone', 'zoo'], dtype=object)

# %%
anime['tags'][0]
# Out:
# 'action adventur comedi drama sci-fi space in the year 2071, human ha colon sever of the planet and moon of the solar system leav the now uninhabit surfac of planet earth behind. the inter solar system polic attempt to keep peac in the galaxy, aid in part by outlaw bounti hunters, refer to as "cowboys." the ragtag team aboard the spaceship bebop are two such individuals. mellow and carefre spike spiegel is balanc by hi boisterous, pragmat partner jet black as the pair make a live chase bounti and collect rewards. thrown off cours by the addit of new member that they meet in their travels—ein, a genet engineered, highli intellig welsh corgi; femm fatal fay valentine, an enigmat trickster with memori loss; and the strang comput whiz kid edward wong—th crew embark on thrill adventur that unravel each member\' dark and mysteri past littl by little. well-balanc with high densiti action and light-heart comedy, cowboy bebop is a space western classic and an homag to the smooth and improvis 
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similar = cosine_similarity(vectors)

# %%
sorted(list(enumerate(similar[0])),reverse=True,key=lambda x:x[1])
# Out:
# [(0, 1.0000000000000002),
#  (3215, 0.3587974807379617),
#  (1025, 0.32740420843989465),
#  (2261, 0.3105295017040594),
#  (4140, 0.3028960741674143),
#  (2047, 0.295084445425327),
#  (5483, 0.295084445425327),
#  (1161, 0.2942449431682499),
#  (290, 0.2909689950691096),
#  (3830, 0.28949874578229834),
#  (6305, 0.2848849246447679),
#  (1174, 0.2845213189769459),
#  (1172, 0.28361519782546996),
#  (6234, 0.2824539250572026),
#  (6610, 0.2817180849095056),
#  (10069, 0.2817180849095056),
#  (4956, 0.28171808490950556),
#  (2460, 0.28057127097270335),
#  (1828, 0.27888667551135854),
#  (2526, 0.27640932763225706),
#  (1, 0.27044936151312526),
#  (735, 0.2675366270879163),
#  (10056, 0.2630850280886955),
#  (13374, 0.26186146828319085),
#  (1332, 0.2616437816143707),
#  (10410, 0.26037552585080104),
#  (4416, 0.26035958758213307),
#  (3825, 0.2602400194529422),
#  (6459, 0.2602400194529422),
#  (975, 0.2584660381784219),
#  (2419, 0.25819888974716115),
#  (1419, 0.25622938051817845),
# ...

# %%
def recommend(anime_name):
    anime_index = anime[anime['Title']==anime_name].index[0]
    distances = similar[anime_index]
    anime_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    for i in anime_list:
        print(anime.iloc[i[0]].Title)

# %%
recommend('Trigun')
# Out:
# Yojouhan Shinwa Taikei
# Araiguma Rascal
# Captain Future
# Tensei shitara Slime Datta Ken
# Trigun: Badlands Rumble

# %%
import pickle

# %%
pickle.dump(anime.to_dict(),open('anime.pkl','wb'))

# %%
anime
# Out:
#        Anime_id                            Title  \
# 0             1                     Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira
# 2             6                           Trigun
# 3             7               Witch Hunter Robin
# 4             8                   Bouken Ou Beet
# ...         ...                              ...
# 15061     40055                      Orbital Era
# 15063     40057            Akai Hana Shiroi Hana
# 15064     40058                    Arui Tekoteko
# 15065     40059          Golden Kamuy 3rd Season
# 15074     40074                          Gibiate
#
#                                                     tags
# 0      action adventur comedi drama sci-fi space in t...
# 1      action space drama mysteri sci-fi anoth day, a...
# 2      action sci-fi adventur comedi drama shounen va...
# 3      action magic polic supernatur drama mysteri wi...
# 4      adventur fantasi shounen supernatur it is the ...
# ...

# %%
pip freeze > requirements.txt

# %%
pickle.dump(similar,open('similar.pkl','wb'))
